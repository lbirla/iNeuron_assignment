# %%
# %config Completer.use_jedi = False #this is command used for enable autocompletion in jupyter notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# qus.1 We have the min and max temperatures in a city In India for each months of the year.
# We would like to find a function to describe this and show it graphically, the dataset
# given below.
# Task:
# 1.fitting it to the periodic function
# 2.plot the fit
# Data
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18
# #this is reference link : https://machinelearningmastery.com/curve-fitting-with-python/

# %%
data = {
    "Max_temp":[39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25],
    "Min_temp":[21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Max_temp  Min_temp
# 0         39        21
# 1         41        23
# 2         43        27
# 3         47        28
# 4         49        32
# 5         51        35
# 6         45        31
# 7         38        28
# 8         37        21
# 9         29        19
# 10        27        17
# 11        25        18

# %%
maths=np.arange(12)
plt.plot(maths,df["Max_temp"], "ro")
plt.plot(maths,df["Min_temp"], "bo")
plt.xlabel("Month")
plt.ylabel("Temperature (' C)")
#plt.axis([0,12,0,60])
# Out:
# C:\Users\SANU\Miniconda3\lib\site-packages\matplotlib\cbook\__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\SANU\Miniconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0,0.5,"Temperature (' C)")

# %%
import numpy as np
from scipy import optimize
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt

# %%
x=df['Max_temp'] 
y=df['Min_temp']
months = np.arange(12)
def temp(a,b,c,d):
    return a * np.sin(b - x) + c * x**2 + d

res_max,cov_max=curve_fit(temp,months,x)
res_min,cov_min=curve_fit(temp,months,y)

# %%
days = np.linspace(0, 12, num=365)
plt.figure()
plt.plot(months,x,'ro')
plt.plot(months,temp(months,*res_max),"r-")
plt.plot(months,y,'bo')
plt.plot(months,temp(months,*res_min),"b-")
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')
plt.show()
# Out:
# C:\Users\SANU\Miniconda3\lib\site-packages\matplotlib\cbook\__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\SANU\Miniconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [raw]
# above curv fit is not best fit

# %%
from scipy import optimize
x=df['Max_temp'] 
y=df['Min_temp']
months = np.arange(12)
#a=times, b=avg, c=ampl,d= time_offset
def temp(a,b,c,d):
    return (b+c*np.cos((a+d)*2*np.pi/a.max()))

res_max,cov_max=curve_fit(temp,months,x,[40, 20, 0])
res_min,cov_min=curve_fit(temp,months,y,[-40, 20, 0])
days = np.linspace(0, 12, num=365)
plt.figure()
plt.plot(months,x,'ro')
plt.plot(days,temp(days,*res_max),"r-")
plt.plot(months,y,'bo')
plt.plot(months,temp(months,*res_min),"b-")
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')
plt.show()

# %% [markdown]
# # que.2 This assignment is for visualization using matplotlib:
# 1. Create a pie chart presenting the male/female proportion
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv")

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df=titanic

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %% [markdown]
# # 1. Create a pie chart presenting the male/female proportion

# %%
z=df['sex'].value_counts()

# %%
plt.pie(z,labels=['male','female'],autopct='%1.1f%%',colors=['blue','red'])
# Out:
# ([<matplotlib.patches.Wedge at 0x11e1e738ac8>,
# ...
#  [Text(-0.480837,0.989341,'male'), Text(0.480837,-0.989341,'female')],
#  [Text(-0.262275,0.539641,'64.4%'), Text(0.262275,-0.539641,'35.6%')])

# %% [markdown]
# # 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
a=df['fare']
b=df['age']

# %%
plt.scatter(a,b)

# %%
df[df.sex=='female']
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6        1.0       1.0                Andrews, Miss. Kornelia Theodosia
# 8        1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286     3.0       1.0  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290     3.0       1.0                 Wilkes, Mrs. James (Ellen Needs)
# 1300     3.0       1.0          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1305     3.0       0.0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df[df.sex=='male']
# Out:
#       pclass  survived                                  name   sex      age  \
# 1        1.0       1.0        Allison, Master. Hudson Trevor  male   0.9167
# 3        1.0       0.0  Allison, Mr. Hudson Joshua Creighton  male  30.0000
# 5        1.0       1.0                   Anderson, Mr. Harry  male  48.0000
# 7        1.0       0.0                Andrews, Mr. Thomas Jr  male  39.0000
# 9        1.0       0.0               Artagaveytia, Mr. Ramon  male  71.0000
# ...      ...       ...                                   ...   ...      ...
# 1302     3.0       0.0                     Yousif, Mr. Wazli  male      NaN
# 1303     3.0       0.0                 Yousseff, Mr. Gerious  male      NaN
# 1306     3.0       0.0             Zakarian, Mr. Mapriededer  male  26.5000
# 1307     3.0       0.0                   Zakarian, Mr. Ortin  male  27.0000
# 1308     3.0       0.0                    Zimmerman, Mr. Leo  male  29.0000
#
# ...

# %%
plt.figure()
category1=df[df.sex=='female'].plot.scatter('age','fare', label='female', color='red')
df[df.sex=='male'].plot.scatter('age','fare',label='male',color="blue",ax=category1)
